# %% [markdown]
# # LINEAR REGRESSION MODEL TRAINING PROJECT

# %% [markdown]
#  linear regeression holds coverage of linear dataset giving the solution and prediction of the continuous dataset, polynomial regresion deals with non linear datasets which contain more parameters than the linear regression makes it more prone to overfitting the traiing dataset

# %%
#a function that accept 5 numbers and returns the average of those numbers
def average_of_five(a, b, c, d, e):
    aver =  (a + b + c + d + e) / 5
average_of_five(2,3,4,5,6)
print("this is the aveage",average_of_five)
# Out:
# this is the aveage <function average_of_five at 0x000001ABA812EFC0>

# %% [markdown]
# Write a function that accepts a single argument N
# , and returns the largest square number that is less than or equal to N
# .

# %%
import math
def singlearr(num:int,arr:int):
    results = []    
    while num<= arr:
        results.append(math.sqrt(num))
        num +=1
    return results
print(singlearr(1,10))
# Out:
# [1.0, 1.4142135623730951, 1.7320508075688772, 2.0, 2.23606797749979, 2.449489742783178, 2.6457513110645907, 2.8284271247461903, 3.0, 3.1622776601683795]

# %%
#this here we have printed the quotient
def TwoArgs(a,b):
    remainder  = float(a/b)
    return remainder
TwoArgs(1,3)
# Out:
# 0.3333333333333333

# %%
def TwoArgs(a, b):
    if b == 0:
        return "Error: Division by zero"
    quotient = a // b  # Integer division
    remainder = a - (b * quotient)
    return remainder

print(TwoArgs(1, 3))   # Output: 1
# Out:
# 1

# %%
def Arg(N):
    
    for i in range(1,N+1):
        if N%i == 0:
            print(i)
print(Arg(4))
# Out:
# 1
# 2
# 4
# None

# %%
def count_factors(N):
    count = 0
    for i in range(1, N + 1):
        if N % i == 0:
            count += 1
    return count

print(count_factors(18))  # Output: 6
# Out:
# 6

# %% [markdown]
# importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing the dataset

# %%
df = pd.read_csv("boxoffice.csv",encoding='latin-1')
df.size
# Out:
# 26940

# %%
df.head
# Out:
# <bound method NDFrame.head of               title  domestic_revenue  world_revenue   distributor  \
# 0      The Avengers           6026491     1274885664  Warner Bros.
# 1           Titanic         169411543     1132871091        Disney
# 2     Jurassic Park         107836098      583329845          Sony
# 3            Avatar          51433697     1225323391        Disney
# 4     The Lion King         142791649      604140729  Warner Bros.
# ...             ...               ...            ...           ...
# 2689          X-Men          38153242       47601900        Disney
# 2690     The Matrix          63305093      252473529        Disney
# 2691   Forrest Gump         271758510      524896297        Disney
# 2692           Jaws         268259149      791515453        Disney
# 2693   Interstellar         158336835       77904664     Universal
#
#       opening_revenue  opening_theaters     budget   MPAA     genres  \
# ...

# %%
df.shape
# Out:
# (2694, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of               title  domestic_revenue  world_revenue   distributor  \
# 0      The Avengers           6026491     1274885664  Warner Bros.
# 1           Titanic         169411543     1132871091        Disney
# 2     Jurassic Park         107836098      583329845          Sony
# 3            Avatar          51433697     1225323391        Disney
# 4     The Lion King         142791649      604140729  Warner Bros.
# ...             ...               ...            ...           ...
# 2689          X-Men          38153242       47601900        Disney
# 2690     The Matrix          63305093      252473529        Disney
# 2691   Forrest Gump         271758510      524896297        Disney
# 2692           Jaws         268259149      791515453        Disney
# 2693   Interstellar         158336835       77904664     Universal
#
#       opening_revenue  opening_theaters     budget   MPAA     genres  \
# ...

# %%
df.describe()
# Out:
#        domestic_revenue  world_revenue  opening_revenue  opening_theaters  \
# count      2.694000e+03   2.694000e+03     2.694000e+03       2694.000000
# mean       1.508539e+08   7.719177e+08     9.971321e+07       2263.039347
# std        8.579997e+07   4.284414e+08     5.721762e+07       1298.559140
# min        8.277650e+05   3.261301e+06     1.385690e+05         10.000000
# 25%        7.673272e+07   3.991135e+08     5.033848e+07       1161.000000
# 50%        1.525725e+08   7.665551e+08     9.981418e+07       2271.500000
# 75%        2.247314e+08   1.143920e+09     1.489805e+08       3392.250000
# max        2.998107e+08   1.499310e+09     1.999336e+08       4499.000000
#
#              budget  release_days
# count  2.694000e+03   2694.000000
# mean   1.537996e+08     90.897550
# std    8.557624e+07     50.894041
# min    5.197977e+06      1.000000
# 25%    7.861876e+07     47.000000
# 50%    1.562567e+08     91.000000
# 75%    2.274832e+08    135.000000
# ...

# %%
df.describe().T
# Out:
#                    count          mean           std        min           25%  \
# domestic_revenue  2694.0  1.508539e+08  8.579997e+07   827765.0  7.673272e+07
# world_revenue     2694.0  7.719177e+08  4.284414e+08  3261301.0  3.991135e+08
# opening_revenue   2694.0  9.971321e+07  5.721762e+07   138569.0  5.033848e+07
# opening_theaters  2694.0  2.263039e+03  1.298559e+03       10.0  1.161000e+03
# budget            2694.0  1.537996e+08  8.557624e+07  5197977.0  7.861876e+07
# release_days      2694.0  9.089755e+01  5.089404e+01        1.0  4.700000e+01
#
#                           50%           75%           max
# domestic_revenue  152572473.5  2.247314e+08  2.998107e+08
# world_revenue     766555142.5  1.143920e+09  1.499310e+09
# opening_revenue    99814175.0  1.489805e+08  1.999336e+08
# opening_theaters       2271.5  3.392250e+03  4.499000e+03
# budget            156256716.0  2.274832e+08  2.998597e+08
# release_days             91.0  1.350000e+02  1.790000e+02

# %%
to_remove = ['world_revenue','opening_revenue']

# %%
df.drop(to_remove,axis=1,inplace=True)

# %%
df.describe().T
# Out:
#                    count          mean           std        min          25%  \
# domestic_revenue  2694.0  1.508539e+08  8.579997e+07   827765.0  76732721.25
# opening_theaters  2694.0  2.263039e+03  1.298559e+03       10.0      1161.00
# budget            2694.0  1.537996e+08  8.557624e+07  5197977.0  78618761.50
# release_days      2694.0  9.089755e+01  5.089404e+01        1.0        47.00
#
#                           50%           75%          max
# domestic_revenue  152572473.5  2.247314e+08  299810741.0
# opening_theaters       2271.5  3.392250e+03       4499.0
# budget            156256716.0  2.274832e+08  299859703.0
# release_days             91.0  1.350000e+02        179.0

# %%
#chceking the misssing value
df.isnull()
# Out:
#       title  domestic_revenue  distributor  opening_theaters  budget   MPAA  \
# 0     False             False        False             False   False  False
# 1     False             False        False             False   False  False
# 2     False             False        False             False   False  False
# 3     False             False        False             False   False  False
# 4     False             False        False             False   False  False
# ...     ...               ...          ...               ...     ...    ...
# 2689  False             False        False             False   False  False
# 2690  False             False        False             False   False  False
# 2691  False             False        False             False   False  False
# 2692  False             False        False             False   False  False
# 2693  False             False        False             False   False  False
#
#       genres  release_days
# 0      False         False
# ...

# %%
#seems like there is no null value in the given data set
#calculating the percentage of values in the missing value in each colummn
df.isnull().sum()*100/df.shape[0]#the rows are access by 0 in these libraries and the columns are acessed by 1
# Out:
# title               0.0
# domestic_revenue    0.0
# distributor         0.0
# opening_theaters    0.0
# budget              0.0
# MPAA                0.0
# genres              0.0
# release_days        0.0
# dtype: float64

# %%
#seems like th dataseet doesnt have any null values in it
'''we clean the missing values 
1. drop the budget column entirely likely due to too many missing values    '''
df.drop('budget',axis=1,inplace = True)
for col in ['MPAA','genres']:
    df[col] = df[col].fillna(df[col].mode()[0])
df.dropna(inplace=True)
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#cleaning numeric columns stores as the string
df['domestic_revenue'] = df['domestic_revenue'].astype(str).str[1:]
for col in ['domestic_revenue','opening_theaters','release_days']:
    df[col] = df[col].astype(str).str.replace(',','')

    temp = (~df[col].isnull())
    df[temp][col] = df[temp][col].convert_dtypes(float)

    df[col] = pd.to_numeric(df[col],errors='coerce')

# %%
#visualizing the MPAA rating distribution
#my data is numerical so we are gonna ise histogra here as we are seeing the division of count of movuies falling iuner the mpaa category
plt.figure(figsize=(10,5))
sns.countplot(df['MPAA'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#we group the MPAA category and calculate the mean(average)of the domestic_revenue
df.groupby('MPAA')['domestic_revenue'].mean()
# Out:
# MPAA
# G        3.426099e+07
# NC-17    3.452006e+07
# PG       3.697347e+07
# PG-13    3.510989e+07
# R        3.670206e+07
# Name: domestic_revenue, dtype: float64

# %%
#pg13 and R has the most revenue as per the mean telling us
plt.subplots(figsize = (15,5))

features = ['domestic_revenue','opening_theaters','release_days']
for i,col in enumerate(features):
    plt.subplot(1,3,i+1)
    sns.displot(df[col])
plt.tight_layout()
plt.show()

# %%
plt.subplots(figsize=(15, 5))

features = ['domestic_revenue', 'opening_theaters', 'release_days']
for i, col in enumerate(features):
    plt.subplot(1, 3, i+1)
    sns.histplot(data=df, x=col, kde=True)
    plt.title('col')
plt.tight_layout()
plt.show()

# %%
#detectying outliners using boxplots
#we use outliners to spread the range of data and detect the outliners in it
plt.subplots(figsize = (15,5))
for i, col in enumerate(features):
    plt.subplot(1,3,i+1)
    sns.boxplot(df[col])
plt.tight_layout()
plt.show()

# %%
#applying log transformation to numeric features
'''we apply log transformers to reduce skewness in the given data becase log transformation often increase the model performance and stability'''
for col in features:
    df[col] = df[col].apply(lambda x:np.log10(x))

# %%
#checking the distributions after the log transformation
plt.subplots(figsize=(15,5))
for i,col in enumerate(features):
    plt.subplot(1,3,i+1)
    sns.histplot(data=df,x = col,kde = True)
    plt.title('col')
plt.tight_layout()
plt.show()

# %%
#we gonna use one hotcoding now to convertt the genre part into numeric features
#we use countvectorizer to convert strings into binary like 1,etc
from  sklearn.feature_extraction.text import CountVectorizer
# vectorizer = CountVectorizer()
# vectorizer.fit_transform(df['genres'])
# features = vectorizer.transform(df['genres'])

# genres = vectorizer.get_features_names_out()
# for i,name in enumerate(genres):
#     df[name] = features[:,i]

# df.drop('genres',axis=1,inplace=True)
#You're calling .toarray() on df['genres'], which is a Pandas Series, not a sparse matrix. The .toarray() method is meant for scipy sparse matrices, not Series.
#def this is gonna give error here

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Step 1: Initialize the vectorizer
vectorizer = CountVectorizer()

# Step 2: Fit and transform the 'genres' column
features = vectorizer.fit_transform(df['genres'])  # NO .toarray() here

# Step 3: Get the genre names (columns)
genres = vectorizer.get_feature_names_out()

# Step 4: Convert features (sparse matrix) to DataFrame
genre_df = pd.DataFrame(features.toarray(), columns=genres)

# Step 5: Concatenate new genre columns with the original df
df = pd.concat([df, genre_df], axis=1)

# Step 6: Drop the original 'genres' column
df.drop('genres', axis=1, inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of               title  domestic_revenue   distributor  opening_theaters   MPAA  \
# 0      The Avengers          4.423098  Warner Bros.          2.403121      R
# 1           Titanic          7.841432        Disney          2.086360      G
# 2     Jurassic Park          6.894100          Sony          3.582745  NC-17
# 3            Avatar          6.156457        Disney          3.587486      G
# 4     The Lion King          7.631359  Warner Bros.          3.467460      R
# ...             ...               ...           ...               ...    ...
# 2689          X-Men          6.911330        Disney          3.548021      G
# 2690     The Matrix          6.519184        Disney          3.501196  PG-13
# 2691   Forrest Gump          7.855873        Disney          3.389166  NC-17
# 2692           Jaws          7.834161        Disney          2.820201      G
# 2693   Interstellar          7.765943     Universal          3.592621  PG-13
#
# ...

# %%
df.describe().T
# Out:
#                    count      mean       std       min       25%       50%  \
# domestic_revenue  2694.0  7.203389  0.707118  3.899711  6.750799  7.435939
# opening_theaters  2694.0  3.224909  0.422307  1.000000  3.064832  3.356313
# release_days      2694.0  1.841056  0.392447  0.000000  1.672098  1.959041
# action            2694.0  0.168894  0.374728  0.000000  0.000000  0.000000
# animation         2694.0  0.173719  0.378938  0.000000  0.000000  0.000000
# comedy            2694.0  0.175575  0.380529  0.000000  0.000000  0.000000
# drama             2694.0  0.160356  0.367004  0.000000  0.000000  0.000000
# horror            2694.0  0.158872  0.365624  0.000000  0.000000  0.000000
# thriller          2694.0  0.162584  0.369054  0.000000  0.000000  0.000000
#
#                        75%       max
# domestic_revenue  7.800098  7.999964
# opening_theaters  3.530488  3.653116
# release_days      2.130334  2.252853
# action            0.000000  1.000000
# ...

# %%
#removing rare genre columns with mostly zero values
removed = 0
if 'actions' in df.columns and 'western' in df.columns:
    for col in df.loc[:,'western':'actions'].columns:

        if (df[col] == 0).mean()>0.95:
            removed +=1
            df.drop(col,axis=1,inplace=True)
print(removed)
print(df.shape)
# Out:
# 0
# (2694, 12)

# %%
#encoding categorial columns int numericals 
from sklearn.preprocessing import LabelEncoder
le  = LabelEncoder()
df[col] = le.fit_transform(df[col])
print(df[col])#we applied this but this couldnt get us the labelencoding into the string operated enteries  for that we gonna run a for loop in the columns
# Out:
# 0        15
# 1       102
# 2        88
# 3        84
# 4       157
#        ...
# 2689     91
# 2690    155
# 2691    145
# 2692    169
# 2693    169
# Name: release_days, Length: 2694, dtype: int64

# %%
#visualizing using numerical visualizers
plt.figure(figsize=(8,8))
sns.heatmap(df.select_dtypes(include=np.number).corr()>0.8,
            annot=True,
            cbar=False)
plt.show()

# %%
# prepare dataset for model training and validation
#we are gonna split the data into training and test set
from sklearn.model_selection import train_test_split
features = df.drop( ['title','domestic_revenue'],axis=1)
target = df['domestic_revenue'].values
x_train,x_val,y_train,y_val  = train_test_split(features,target,test_size=0.1,random_state=22)
x_train.shape,x_val.shape
# Out:
# ((2424, 10), (270, 10))

# %%
from sklearn.preprocessing import LabelEncoder
#applying label encoder to each object column
for col in x_train.select_dtypes(include='object').columns:
    le = LabelEncoder()
    x_train[col] = le.fit_transform(x_train[col])
    x_val[col] = le.transform(x_val[col])

# %%
#normalizing featurs for training
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %%
#applying the regression model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_val)

# %%
# visualizing the result
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_val,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_val,y_pred)
print(mse)
print(rmse)
print(r2)
# Out:
# 0.4387112429410619
# 0.6623528085099828
# -0.008594525976191703

# %%
#visualization
plt.figure(figsize = (8,5))
plt.scatter(y_val,y_pred,color = 'blue')
plt.xlabel('actual revenue')
plt.ylabel('predicted revenue')
plt.title("actual vs predicted")
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], color='red', linestyle='--')  # line y = x
plt.show()
